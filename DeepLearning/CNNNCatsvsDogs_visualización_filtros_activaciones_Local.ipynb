# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import numpy as np
import os

IMG_SIZE = 128
BATCH = 32

train = keras.utils.image_dataset_from_directory(
    "cats_vs_dogs/train",
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH
)

val = keras.utils.image_dataset_from_directory(
    "cats_vs_dogs/val",
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH
)

# Normalizar
norm = layers.Rescaling(1./255)
train = train.map(lambda x,y: (norm(x), y))
val   = val.map(lambda x,y: (norm(x), y))

# CNN igual que arriba
model = keras.Sequential([
    layers.Conv2D(32, 3, activation='relu', input_shape=(IMG_SIZE, IMG_SIZE, 3)),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(128, 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
history = model.fit(train, validation_data=val, epochs=3)

# Visualizaciones: usa el mismo código de "filtros" y "activaciones" de la Opción A
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[1], line 11
#       8 IMG_SIZE = 128
#       9 BATCH = 32
# ---> 11 train = keras.utils.image_dataset_from_directory(
#      12     "cats_vs_dogs/train",
#      13     image_size=(IMG_SIZE, IMG_SIZE),
#      14     batch_size=BATCH
#      15 )
#      17 val = keras.utils.image_dataset_from_directory(
#      18     "cats_vs_dogs/val",
#      19     image_size=(IMG_SIZE, IMG_SIZE),
#      20     batch_size=BATCH
#      21 )
#      23 # Normalizar
#
# ...
