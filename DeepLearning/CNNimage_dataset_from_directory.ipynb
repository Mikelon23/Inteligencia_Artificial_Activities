# %% [markdown]
# ***Cargar datos + normalizar***

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np, matplotlib.pyplot as plt

IMG_SIZE, BATCH = 128, 32

train = keras.utils.image_dataset_from_directory(
    "cats_vs_dogs/train", image_size=(IMG_SIZE, IMG_SIZE), batch_size=BATCH
)

val = keras.utils.image_dataset_from_directory(
    "cats_vs_dogs/val", image_size=(IMG_SIZE, IMG_SIZE), batch_size=BATCH
)

norm = layers.Rescaling(1./255)
train = train.map(lambda x,y: (norm(x), y))
val   = val.map(lambda x,y: (norm(x), y))

# sanity check
print(xb.shape, yb.shape)  # (B, 128, 128, 3) (B,)
# Out:
# Found 0 files belonging to 0 classes.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 8
#       4 import numpy as np, matplotlib.pyplot as plt
#       6 IMG_SIZE, BATCH = 128, 32
# ----> 8 train = keras.utils.image_dataset_from_directory(
#       9     "cats_vs_dogs", image_size=(IMG_SIZE, IMG_SIZE), batch_size=BATCH
#      10 )
#      12 val = keras.utils.image_dataset_from_directory(
#      13     "cats_vs_dogs", image_size=(IMG_SIZE, IMG_SIZE), batch_size=BATCH
#      14 )
#      16 norm = layers.Rescaling(1./255)
#
# File c:\Users\Miguel\Desktop\Miguelon\GH\Inteligencia_Artificial_Activities\.venv\Lib\site-packages\keras\src\utils\image_dataset_utils.py:329, in image_dataset_from_directory(directory, labels, label_mode, class_names, color_mode, batch_size, image_size, shuffle, seed, validation_split, subset, interpolation, follow_links, crop_to_aspect_ratio, pad_to_aspect_ratio, data_format, verbose)
#     325 image_paths, labels = dataset_utils.get_training_or_validation_split(
#     326     image_paths, labels, validation_split, subset
#     327 )
#     328 if not image_paths:
# --> 329     raise ValueError(
#     330         f"No images found in directory {directory}. "
#     331         f"Allowed formats: {ALLOWLIST_FORMATS}"
#     332     )
#     334 dataset = paths_and_labels_to_dataset(
#     335     image_paths=image_paths,
#     336     image_size=image_size,
#    (...)    347     seed=seed,
#     348 )
#     350 if batch_size is not None:
#
# ValueError: No images found in directory cats_vs_dogs. Allowed formats: ('.bmp', '.gif', '.jpeg', '.jpg', '.png')
